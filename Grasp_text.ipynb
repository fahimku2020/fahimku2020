# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimku2020/fahimku2020/blob/main/Grasp_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install grasptext
# Out:
# ...
#   Using cached thinc-7.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# ...
#   Using cached srsly-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# ...
#   Using cached catalogue-1.0.2-py2.py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 2.9 MB/s eta 0:00:00
# Using cached catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Using cached srsly-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (369 kB)
# Using cached thinc-7.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# ...
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.5.0
#     Uninstalling srsly-2.5.0:
#       Successfully uninstalled srsly-2.5.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.10
#     Uninstalling catalogue-2.0.10:
#       Successfully uninstalled catalogue-2.0.10
#   Attempting uninstall: thinc
# ...

# %%
import grasptext

# Step 1: Create the GrASP model
grasp_model = grasptext.GrASP(num_patterns = 50,
                    gaps_allowed = 2,
                    alphabet_size = 50,
                    include_standard = ['LEMMA', 'POS', 'NER', 'HYPERNYM'])

# Step 2: Fit it to the training data
from sklearn.datasets import fetch_20newsgroups
def get_20newsgroups_examples(class_name, num_examples = 5):
    assert num_examples > 0
    data = fetch_20newsgroups(categories=[class_name], shuffle=False, remove=('headers','footers'))['data']
    return data[:min(num_examples, len(data))]

pos_exs = get_20newsgroups_examples('rec.autos', num_examples = 5)
neg_exs = get_20newsgroups_examples('rec.motorcycles', num_examples = 5)
the_patterns = grasp_model.fit_transform(pos_exs, neg_exs)

# Step 3: Export the results

grasp_model.to_json('results.json')
# Out:
# Step 1: Create augmented texts
# ...
# 100%|██████████| 5/5 [00:00<00:00, 21.83it/s]
# Step 2: Find frequent attributes
# Total number of candidate alphabet = 1350, such as ['SPACY:POS-AUX', 'SPACY:POS-PUNCT', 'SPACY:POS-SPACE', 'SPACY:POS-DET', 'SPACY:POS-ADJ']
# Step 3: Find alphabet set
# 100%|██████████| 1350/1350 [00:00<00:00, 2936.89it/s]
# Finding top k: 5 / 50
# Finding top k: 10 / 50
# Finding top k: 15 / 50
# Finding top k: 20 / 50
# Finding top k: 25 / 50
# Finding top k: 30 / 50
# Finding top k: 35 / 50
# Finding top k: 40 / 50
# Finding top k: 45 / 50
# Finding top k: 50 / 50
# Total number of alphabet = 50
# ...

# %%
# !pip install -U spacy thinc spacy-transformers
# Out:
# ...
#   Using cached srsly-2.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.1/29.1 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 71.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.8/197.8 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 54.9 MB/s eta 0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached srsly-2.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 86.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 84.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.2
# ...
