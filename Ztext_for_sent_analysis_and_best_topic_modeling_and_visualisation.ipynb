# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimku2020/fahimku2020/blob/main/Ztext_for_sent_analysis_and_best_topic_modeling_and_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ztext
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 38.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 38.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.4/320.4 kB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 51.2 MB/s eta 0:00:00
# ...
#   Created wheel for ztext: filename=ztext-0.0.8-py3-none-any.whl size=11385 sha256=68e732b3f585cb1704383eb59ed7d2a269bef407ab78ad870a07a27e846f1f16
#   Stored in directory: /root/.cache/pip/wheels/e9/dc/df/d8a387fcb503d313bbf1b0ab44b7c2f846bcb6d2955399eba3
# Successfully built ztext
# ...

# %%
import ztext
import pandas as pd

# %%
df = ztext.sampledata()
zt = ztext.Ztext(df=df, textCol='content',nTopics=5, custom_stopwrods=['sell','home'], samplesize=200)

# %%
zt

# %%
zt.loaddf(df)

# %%
zt.sentiment()
# Out:
# sentment analyzing ...
#      index                                              title  \
# 0     7932  Housing's vicious cycle comes to an end; "It c...
# 1     9345  Fine print; From high-flying politicos to thou...
# 2     3578  2013 Calgary home sales skyrocket; 'Perfect st...
# 3      367  First-time buyers drive market; Account for on...
# 4      427  Multi-family starts soar in January; New apart...
# ..     ...                                                ...
# 495  15656                  Bungalow, condo prices down in Q1
# 496  11915                Greener buildings becoming the norm
# 497  15023  Global cash headed to Vancouver; The low looni...
# 498   6730              Housing market approaches equilibrium
# 499  13707  Luma a beacon for younger households; Polygon ...
#
#                  date             author  wordscount  \
# 0        30 July 2009          JAY BRYAN         724
# 1    21 November 2009   Patrick Langston        1557
# ...

# %%
zt.get_topics()
# Out:
# data need to be cleaned first, cleaning the data
# cleaning text ...
# 100%|██████████| 500/500 [01:40<00:00,  4.97it/s]
# getting topics ...
#      index                                              title  \
# 0     7932  Housing's vicious cycle comes to an end; "It c...
# 1     9345  Fine print; From high-flying politicos to thou...
# 2     3578  2013 Calgary home sales skyrocket; 'Perfect st...
# 3      367  First-time buyers drive market; Account for on...
# 4      427  Multi-family starts soar in January; New apart...
# ..     ...                                                ...
# 495  15656                  Bungalow, condo prices down in Q1
# 496  11915                Greener buildings becoming the norm
# 497  15023  Global cash headed to Vancouver; The low looni...
# 498   6730              Housing market approaches equilibrium
# 499  13707  Luma a beacon for younger households; Polygon ...
#
#                  date             author  wordscount  \
# ...

# %%
zt.getSVO('topic2')

# %%
zt.getldaVis()

zt.getSVOvis('topic2',options="any")

# %%
#from file !wget https://github.com/ZackAnalysis/ztext/blob/master/ztext/sampleData.xlsx?raw=true
filename = "sampleData.xlsx" zt = ztext.Ztext()
zt.loadfile(filename, textCol='content')
zt.nTopics = 6 zt.custom_stopwords = ['text','not','emotion']

# %%
#save output
zt.df.to_excel('filename.xlsx')
