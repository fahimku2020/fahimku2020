# %% [markdown]
# <a href="https://colab.research.google.com/github/fahimku2020/fahimku2020/blob/main/Semantic_search_txtai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/neuml/txtai#egg=txtai[graph]

# Install translation pipeline dependencies for later examples
# !pip install sentencepiece sacremoses fasttext
# Out:
# DEPRECATION: git+https://github.com/neuml/txtai#egg=txtai[graph] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting txtai (from txtai[graph])
#   Cloning https://github.com/neuml/txtai to /tmp/pip-install-21kyto5y/txtai_4bcbfb291b2642099d80395fc907b019
#   Running command git clone --filter=blob:none --quiet https://github.com/neuml/txtai /tmp/pip-install-21kyto5y/txtai_4bcbfb291b2642099d80395fc907b019
#   Resolved https://github.com/neuml/txtai to commit dd92c1866305023415413519401952ca42942436
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting faiss-cpu>=1.7.1.post2 (from txtai->txtai[graph])
#   Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: msgpack>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (1.1.0)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (2.5.1+cu121)
# Requirement already satisfied: transformers>=4.45.0 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (4.47.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (0.27.0)
# Requirement already satisfied: numpy>=1.18.4 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (1.26.4)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (6.0.2)
# Requirement already satisfied: regex>=2022.8.17 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (2024.11.6)
# Collecting grand-cypher>=0.6.0 (from txtai->txtai[graph])
#   Downloading grand-cypher-0.11.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting grand-graph>=0.6.0 (from txtai->txtai[graph])
#   Downloading grand-graph-0.6.0.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (3.4.2)
# Requirement already satisfied: python-louvain>=0.16 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (0.16)
# Requirement already satisfied: sqlalchemy>=2.0.20 in /usr/local/lib/python3.10/dist-packages (from txtai->txtai[graph]) (2.0.36)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu>=1.7.1.post2->txtai->txtai[graph]) (24.2)
# Collecting grandiso (from grand-cypher>=0.6.0->txtai->txtai[graph])
#   Downloading grandiso-2.2.0.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lark-parser (from grand-cypher>=0.6.0->txtai->txtai[graph])
#   Downloading lark_parser-0.12.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from grand-graph>=0.6.0->txtai->txtai[graph]) (2.2.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from grand-graph>=0.6.0->txtai->txtai[graph]) (5.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->txtai->txtai[graph]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->txtai->txtai[graph]) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->txtai->txtai[graph]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->txtai->txtai[graph]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->txtai->txtai[graph]) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0.20->txtai->txtai[graph]) (3.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->txtai->txtai[graph]) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->txtai->txtai[graph]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.12.1->txtai->txtai[graph]) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0->txtai->txtai[graph]) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0->txtai->txtai[graph]) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->txtai->txtai[graph]) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->grand-graph>=0.6.0->txtai->txtai[graph]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->grand-graph>=0.6.0->txtai->txtai[graph]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->grand-graph>=0.6.0->txtai->txtai[graph]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->txtai->txtai[graph]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->txtai->txtai[graph]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->txtai->txtai[graph]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->txtai->txtai[graph]) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->grand-graph>=0.6.0->txtai->txtai[graph]) (1.17.0)
# Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 64.0 MB/s eta 0:00:00
# Downloading lark_parser-0.12.0-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 10.2 MB/s eta 0:00:00
# Building wheels for collected packages: txtai, grand-cypher, grand-graph, grandiso
#   Building wheel for txtai (pyproject.toml) ... done
#   Created wheel for txtai: filename=txtai-8.2.0-py3-none-any.whl size=258407 sha256=2652fb178e7d24c187b8b6e05d08ae574e764de4c976ace68b410bba25a49321
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hixj47xd/wheels/e6/e6/c9/22c5eba7f37d8447b84d13a00ddce3494350e984debb790584
#   Building wheel for grand-cypher (setup.py) ... done
#   Created wheel for grand-cypher: filename=grand_cypher-0.11.0-py3-none-any.whl size=25247 sha256=206d69f88cfc2e3a813746161a5fc1fde271307e3f17df3d518466d295cfe627
#   Stored in directory: /root/.cache/pip/wheels/d6/45/55/41f3e7ecd66ca83d28141009a90654af36e0766d2e21d0730c
#   Building wheel for grand-graph (setup.py) ... done
#   Created wheel for grand-graph: filename=grand_graph-0.6.0-py3-none-any.whl size=36512 sha256=f61cdace4dafb7d601231e40c101f23622794ef2c3bed1b8c0887736a87b0d30
#   Stored in directory: /root/.cache/pip/wheels/f1/0d/43/fe1c4fb05524e190396adbdc61855a778c541fbb8640572367
#   Building wheel for grandiso (setup.py) ... done
#   Created wheel for grandiso: filename=grandiso-2.2.0-py3-none-any.whl size=15809 sha256=bbc27cd05e7104bd95ab7093d2a56d26760a0614608192ed8c630d0235f25e6c
#   Stored in directory: /root/.cache/pip/wheels/61/f2/5a/9c49f5896a0ba3f2419a34d7ad72e67256e9a336b4eb7f9c0c
# Successfully built txtai grand-cypher grand-graph grandiso
# Installing collected packages: lark-parser, grandiso, faiss-cpu, grand-cypher, grand-graph, txtai
# Successfully installed faiss-cpu-1.9.0.post1 grand-cypher-0.11.0 grand-graph-0.6.0 grandiso-2.2.0 lark-parser-0.12.0 txtai-8.2.0
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2024.11.6)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.67.1)
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 19.2 MB/s eta 0:00:00
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4296186 sha256=f2de47d282bb855852cea74c9c756d3b3135e6d03a5c7d3251cb428ab7c1be9c
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: sacremoses, pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.6 sacremoses-0.1.1

# %%
from txtai import Embeddings

# Works with a list, dataset or generator

embeddings = Embeddings(path="sentence-transformers/nli-mpnet-base-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
documents =["Amitabh Bachchan (pronounced [əmɪˈt̪ɑːbʱ ˈbətːʃən] ; born Amitabh Srivastava; 11 October 1942) is an Indian actor who works in Hindi cinema",
 "He is often considered one of the greatest, most accomplished and commercially successful actors in the history of Indian cinema",
 " With a cinematic career spanning over five decades, he has played pivotal roles in over 200 films",
 " Bachchan is often hailed as the Shahenshah of Bollywood, Sadi Ke Mahanayak (translated as in Hindi), Star of the Millennium, or simply Big B",
 "His dominance in the Indian film industry during the 1970s–80s led the French director François Truffaut to describe it as a one-man industry",
 "He is a recipient of several accolades including six National Film Awards and sixteen Filmfare Awards",
 "Amitabh Bachchan was born in 1942 in Allahabad (now Prayagraj) to the Hindi poet Harivansh Rai Bachchan and his wife, the social activist Teji Bachchan",
 "He was educated at Sherwood College, Nainital, and Kirori Mal College, University of Delhi",
 " His film career started in 1969 as a voice narrator in Mrinal Sen's film Bhuvan Shome", ]

# %%
embeddings.index(documents  )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-25c7b79bc351> in <cell line: 1>()
# ----> 1 embeddings.index(doc )
#
# /usr/local/lib/python3.10/dist-packages/txtai/embeddings/base.py in index(self, documents, reindex)
#     122         with tempfile.NamedTemporaryFile(mode="wb", suffix=".npy") as buffer:
#     123             # Load documents into database and transform to vectors
# --> 124             ids, dimensions, embeddings = transform(stream(documents), buffer)
#     125             if embeddings is not None:
#     126                 # Build LSA model (if enabled). Remove principal components from embeddings.
#
# /usr/local/lib/python3.10/dist-packages/txtai/embeddings/index/transform.py in __call__(self, documents, buffer)
#      73
#      74         if self.model:
# ---> 75             ids, dimensions, embeddings = self.vectors(documents, buffer)
#      76         else:
#      77             ids = self.ids(documents)
#
# /usr/local/lib/python3.10/dist-packages/txtai/embeddings/index/transform.py in vectors(self, documents, buffer)
#      92
#      93         # Consume stream and transform documents to vectors
# ---> 94         ids, dimensions, batches, stream = self.model.index(self.stream(documents), self.batch)
#      95
#      96         # Check that embeddings are available and load as a memmap
#
# /usr/local/lib/python3.10/dist-packages/txtai/vectors/base.py in index(self, documents, batchsize)
#     125                 if len(batch) == batchsize:
#     126                     # Convert batch to embeddings
# --> 127                     uids, dimensions = self.batch(batch, output)
#     128                     ids.extend(uids)
#     129                     batches += 1
#
# /usr/local/lib/python3.10/dist-packages/txtai/vectors/base.py in batch(self, documents, output)
#     199
#     200         # Build embeddings
# --> 201         embeddings = self.vectorize(documents)
#     202         if embeddings is not None:
#     203             dimensions = embeddings.shape[1]
#
# /usr/local/lib/python3.10/dist-packages/txtai/vectors/base.py in vectorize(self, data)
#     269
#     270         # Transform data into vectors
# --> 271         embeddings = self.encode(data)
#     272
#     273         if embeddings is not None:
#
# /usr/local/lib/python3.10/dist-packages/txtai/vectors/huggingface.py in encode(self, data)
#      42     def encode(self, data):
#      43         # Encode data using vectors model
# ---> 44         return self.model.encode(data, batch=self.encodebatch)
#
# /usr/local/lib/python3.10/dist-packages/txtai/models/pooling/base.py in encode(self, documents, batch)
#      72             # Run inputs through model
#      73             with torch.no_grad():
# ---> 74                 outputs = self.forward(**inputs)
#      75
#      76             # Add batch result
#
# /usr/local/lib/python3.10/dist-packages/txtai/models/pooling/mean.py in forward(self, **inputs)
#      25
#      26         # Run through transformers model
# ---> 27         tokens = super().forward(**inputs)
#      28         mask = inputs["attention_mask"]
#      29
#
# /usr/local/lib/python3.10/dist-packages/txtai/models/pooling/base.py in forward(self, **inputs)
#     105         """
#     106
# --> 107         return self.model(**inputs)[0]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     542         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     543         embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 544         encoder_outputs = self.encoder(
#     545             embedding_output,
#     546             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     332                 all_hidden_states = all_hidden_states + (hidden_states,)
#     333
# --> 334             layer_outputs = layer_module(
#     335                 hidden_states,
#     336                 attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     301         outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#     302
# --> 303         intermediate_output = self.intermediate(attention_output)
#     304         layer_output = self.output(intermediate_output, attention_output)
#     305         outputs = (layer_output,) + outputs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states)
#     255
#     256     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 257         hidden_states = self.dense(hidden_states)
#     258         hidden_states = self.intermediate_act_fn(hidden_states)
#     259         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# Create an index for the list of text
#embeddings.index(documents )

print("%-20s %s" % ("Query", "Best Match"))
print("-" * 50)

# Run an embeddings search for each query
for query in ("Award","film","roles","education"):
  # Extract uid of first result
  # search result format: (uid, score)
  uid = embeddings.search(query, 1)[0 ][0]

  # Print text
  print("%-20s %s" % (query, documents[uid]))
# Out:
# Query                Best Match
# --------------------------------------------------
# Award                a
# film                 ɑ
# roles                ə
# education            ɑ
